# %% [markdown]
# #  Exploring Ebay Car Sales Data
# I will be working with a dataset of used cars in 2015 - 2016 from eBay Kleinanzeigen - a classified section of the German eBay website.
#
# The goal is to clean and then analyze this dataset. The dataset samples 50,000 data points from the full dataset.
#
# Column Names and Descriptions:
# *  name - car name
# *  seller - private or dealer
# *  offerType - type of listing
# *  price - price on the ad to sell the car, euro?
# *  abtest - whether the listing is included in an A/B test
# *  vehicleType - vehicle type
# *  yearOrfRegistration - year the car was first registered
# *  gearbox - transmission type
# *  powerPS - power of the car in ps
# *  model - car model name
# *  kilometer - total kilos the car has driven
# *  monthOfRegistration - month the car was first registered
# *  fuelType - what type of fuel the car uses
# *  brand - brand of the car
# *  notRepairedDamage - if the car has damage which is not yet repaired
# *  dateCreated - when the ebay listing was created
# *  nrOfPictures - number of pictures in the ad
# *  postalCode - location of the vehicle
# *  lastSeenOnline - when the cralwer saw this ad last online

# %%
#importing these important libraries
import pandas as pd
import numpy as np

autos=pd.read_csv("autos.csv",encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
#retrive basic info about the data I am working with
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# Observation: In looking at the first few rows of the autos dataframe and the dataframe information, I can make the following observations:
# 1) 15 rows of the dataframe are a string and 5 rows are of integer datatype
# 2) There are 50,000 rows of used car info and 20 columns
# 3) The following columns have some null values: vehicleType, gearbox, modle, fuelType, notRepairedDamage

# %%
#how are the column titles formatted, change those which I don't like
header=autos.columns.copy()
header=["date_crawled","name","seller","offer_type","price","abtest","vehicle_type","registration_year","gearbox","power_ps","model","odometer","registration_month","fuel_type","brand","unrepaired_damage","ad_created","nr_of_pictures","postal_code","last_seen"]
print(header)
# Out:
# ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest', 'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model', 'odometer', 'registration_month', 'fuel_type', 'brand', 'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code', 'last_seen']

# %%
autos.columns=header

# %% [markdown]
# I made some changes to the column labels by
# 1) shortening some of the longer columns
# 2) separating words with _ to make the phrases clearer
# 3) changing all of labels to lowercase

# %%
#investigate the stats of the object or string columns
autos.describe(include=["O"])
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-16 21:50:53  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
#
#        vehicle_type  gearbox  model   odometer fuel_type       brand  \
# count         44905    47320  47242      50000     45518       50000
# unique            8        2    245         13         7          40
# top       limousine  manuell   golf  150,000km    benzin  volkswagen
# freq          12859    36993   4024      32424     30107       10687
#
#        unrepaired_damage           ad_created            last_seen
# count              40171                50000                50000
# unique                 2                   76                39481
# ...

# %% [markdown]
# Now, I will take a look at the data to see what other cleaning needs to be done. Are there any columns to be dropped because they do not provide valuable information? Are there integers, floats, or dates that are stored as strings?
#
# Here are my observations:
# *  nr_of_pictures - I can delete this column because there are only zeroes
# *  date_crawled - convert from string to date
#     -  3/5/3016 - 4/7/2016
# *  seller - only 2 unique values and majority are one value
# *  offer_type - only 2 unique values and majority are one value
# *  price - convert to integer
#     -  min price of 0
#     -  max price of 99,999,999
# *  abtest - only 2 unique values
# *  gearbox - only 2 unique values
# *  odometer - convert to integer
#     -  min is 5,000
#     -  max is 150,000
# *  unrepaired_damage - only 2 unique values
# *  ad_created - convert from string to date
#     -  6/11/2015 - 4/7/2016
# *  last_seen - convert from string to date
#     - 3/5/2016 - 4/7/2016
# *  year_of_registration (integer)
#     -  min is 1000 (bad)
#     -  max is 9999 (bad)
# *  month_of_registration (integer)
#     -  min is 0 (bad)
#     -  max is 12 (good)
#
# Note: times currently formatted as strings are YYYY-MM-DD HH:MM::SS
# All dates took place in 2016.

# %%
#change the format of a few columns 
autos["price"]=autos.loc[:,"price"].str.replace("$","").str.replace(",","").astype("int")
autos["odometer"]=autos.loc[:,"odometer"].str.replace(",","").str.replace("km","").astype("int")
autos.rename({"odometer":"odometer_km"},axis=1,inplace=True)

# %%
#investigate the stats of the integer and float columns
autos.describe()
# Out:
#               price  registration_year      power_ps    odometer_km  \
# count  5.000000e+04       50000.000000  50000.000000   50000.000000
# mean   9.840044e+03        2005.073280    116.355920  125732.700000
# std    4.811044e+05         105.712813    209.216627   40042.211706
# min    0.000000e+00        1000.000000      0.000000    5000.000000
# 25%    1.100000e+03        1999.000000     70.000000  125000.000000
# 50%    2.950000e+03        2003.000000    105.000000  150000.000000
# 75%    7.200000e+03        2008.000000    150.000000  150000.000000
# max    1.000000e+08        9999.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        50000.000000         50000.0  50000.000000
# mean             5.723360             0.0  50813.627300
# std              3.711984             0.0  25779.747957
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30451.000000
# ...

# %%
#investigate unique values and filter out some rows with bad data 
autos["price"].unique().shape
autos["price"].value_counts().sort_index(ascending=True)
autos=autos[~autos["price"].between(0,100)]
autos=autos[~autos["price"].between(10000000,100000000)]
autos["odometer_km"].unique().shape
autos["odometer_km"].value_counts().sort_index(ascending=True)
autos=autos.drop(["nr_of_pictures"],axis=1)

# %% [markdown]
# In the previous step, I have removed rows with "price" between 0 and 100 and over 90,000,000 german dollars. The odometer_km values seem to be within a good range. We have now deleted 1897 rows with poor data. I also deleted the nr_of_photos column because it only contain 0s.

# %%
autos[['date_crawled','ad_created',"last_seen"]][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
#view the number and range of dates relevant to the ad
print(autos["last_seen"].str[:10].value_counts(normalize=True, dropna=False).sort_index(ascending=True))
print(autos["ad_created"].str[:10].value_counts(normalize=True, dropna=False).sort_index(ascending=True))
print(autos["date_crawled"].str[:10].value_counts(normalize=True,dropna=False).sort_index(ascending=True))
# Out:
# 2016-03-05    0.001081
# 2016-03-06    0.004304
# 2016-03-07    0.005385
# 2016-03-08    0.007298
# 2016-03-09    0.009564
# 2016-03-10    0.010645
# 2016-03-11    0.012413
# 2016-03-12    0.023827
# 2016-03-13    0.008878
# 2016-03-14    0.012621
# 2016-03-15    0.015823
# 2016-03-16    0.016425
# 2016-03-17    0.028069
# 2016-03-18    0.007319
# 2016-03-19    0.015760
# 2016-03-20    0.020667
# 2016-03-21    0.020563
# 2016-03-22    0.021374
# 2016-03-23    0.018588
# 2016-03-24    0.019711
# 2016-03-25    0.019108
# 2016-03-26    0.016696
# 2016-03-27    0.015511
# 2016-03-28    0.020813
# 2016-03-29    0.022330
# 2016-03-30    0.024638
# 2016-03-31    0.023848
# 2016-04-01    0.022871
# 2016-04-02    0.024867
# 2016-04-03    0.025137
# 2016-04-04    0.024513
# 2016-04-05    0.125187
# 2016-04-06    0.221952
# 2016-04-07    0.132215
# Name: last_seen, dtype: float64
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# ...

# %% [markdown]
# Note: Let's explore the registration_year more heavily...
# We need to filter out values less than 1900 and greater than or equal to 2018 because car models are a year ahead. For example, in 2016 there could be 2017 modeled cars on the road. Most of the cars are the website were registered between 1994 - 2012 which seems realistic.

# %%
autos["registration_year"].value_counts().sort_index(ascending=True)
# Out:
# 1000       1
# 1001       1
# 1111       1
# 1800       2
# 1910       2
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       1
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       4
# 1959       6
# 1960      21
# 1961       6
# 1962       4
# 1963       8
# 1964      12
#         ...
# 2000    3079
# 2001    2627
# 2002    2475
# 2003    2693
# 2004    2699
# 2005    2909
# 2006    2669
# 2007    2272
# 2008    2209
# 2009    2081
# 2010    1587
# 2011    1617
# 2012    1308
# 2013     800
# 2014     662
# 2015     380
# 2016    1196
# 2017    1382
# 2018     468
# 2019       1
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       3
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       3
# Name: registration_year, Length: 95, dtype: int64

# %%
#filter the data within a realistic timeframe
autos=autos[autos["registration_year"].between(1910,2017)]

# %%
#what percentage of the cars by registration year
autos["registration_year"].value_counts(normalize=True).sort_index(ascending=True)
# Out:
# 1910    0.000042
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000042
# 1937    0.000084
# 1938    0.000021
# 1939    0.000021
# 1941    0.000042
# 1943    0.000021
# 1948    0.000021
# 1950    0.000021
# 1951    0.000042
# 1952    0.000021
# 1953    0.000021
# 1954    0.000042
# 1955    0.000042
# 1956    0.000084
# 1957    0.000042
# 1958    0.000084
# 1959    0.000126
# 1960    0.000441
# 1961    0.000126
# 1962    0.000084
# 1963    0.000168
# 1964    0.000252
# 1965    0.000357
# 1966    0.000462
# 1967    0.000546
# 1968    0.000546
#           ...
# 1988    0.002794
# 1989    0.003592
# 1990    0.006890
# 1991    0.007037
# 1992    0.007688
# 1993    0.008738
# 1994    0.012939
# 1995    0.024723
# 1996    0.028294
# 1997    0.040077
# 1998    0.048794
# 1999    0.060347
# 2000    0.064674
# 2001    0.055180
# 2002    0.051987
# 2003    0.056566
# 2004    0.056692
# 2005    0.061103
# 2006    0.056062
# 2007    0.047723
# 2008    0.046400
# ...

# %%
#What are the most popular brands? 
brand_list=autos["brand"].value_counts()
print(brand_list)
brand_list=brand_list[brand_list>1000]
# Out:
# volkswagen        10129
# bmw                5200
# opel               5132
# mercedes_benz      4585
# audi               4114
# ford               3310
# renault            2261
# peugeot            1409
# fiat               1224
# seat                886
# skoda               771
# nissan              732
# mazda               726
# smart               684
# citroen             672
# toyota              609
# hyundai             476
# sonstige_autos      447
# volvo               432
# mini                416
# mitsubishi          385
# honda               377
# kia                 340
# alfa_romeo          318
# porsche             279
# suzuki              277
# chevrolet           267
# chrysler            168
# dacia               128
# daihatsu            118
# jeep                107
# land_rover           99
# subaru               99
# saab                 78
# daewoo               73
# jaguar               71
# trabant              65
# rover                64
# ...

# %% [markdown]
# Observation: The most popular car barnd is volkswagen. Let's aggregate over brand with over 1,000 registered vehicles in our data set.

# %%
#what is the average price by brand for the top brands
new_dict={}

for item in brand_list.index:
    selected_rows=autos[autos["brand"]==item]
    new_avg=selected_rows["price"].sum(axis=0)/brand_list[item]
    new_dict[item]=new_avg.round(2)

new_dict
# Out:
# {'audi': 9295.3,
#  'bmw': 8570.73,
#  'fiat': 2830.92,
#  'ford': 4086.41,
#  'mercedes_benz': 8574.66,
#  'opel': 2996.52,
#  'peugeot': 3099.36,
#  'renault': 2475.4,
#  'volkswagen': 5596.45}

# %% [markdown]
# Observation: Looking at the most popular cars on eBay, the car brands with the  most expensive average price at 8,000-9,000 are audi, merdeces_benz, bmw.
# The cheapest car is a "renault" with an average price of 2,375.

# %%
#what is the average odometer reading for these popular brands
new_dict2={}

for item in brand_list.index:
    selected_rows=autos[autos["brand"]==item]
    new_avg=selected_rows["odometer_km"].mean(axis=0)
    new_dict2[item]=new_avg.round(2)

# %%
new_dict2
# Out:
# {'audi': 129534.52,
#  'bmw': 132812.5,
#  'fiat': 117148.69,
#  'ford': 124238.67,
#  'mercedes_benz': 131223.56,
#  'opel': 129471.94,
#  'peugeot': 127228.53,
#  'renault': 128246.35,
#  'volkswagen': 129005.82}

# %%
#transform these dictionaries into pandas series
new_dict=pd.Series(new_dict)

# %%
new_dict2=pd.Series(new_dict2)

# %%
#let's combine the odometer and avg price info together into one dataframe

df=pd.DataFrame(new_dict,columns=['avg_price'])
df['avg_odo']=new_dict2
df.sort_values("avg_price")
# Out:
#                avg_price    avg_odo
# renault          2475.40  128246.35
# fiat             2830.92  117148.69
# opel             2996.52  129471.94
# peugeot          3099.36  127228.53
# ford             4086.41  124238.67
# volkswagen       5596.45  129005.82
# bmw              8570.73  132812.50
# mercedes_benz    8574.66  131223.56
# audi             9295.30  129534.52

# %% [markdown]
# Observation: Looking at the average price and the odometer readings for the top few brands witin this dataset, you can see tht the cars that sold for the most don't necessarily have the least amount of mileage on their cars. In fact, the top three brands by price have some of the higher mileage values.

# %% [markdown]
# Next Step #1: Identify categorical data that uses german words, translate them and map the values to their english counterparts.
#
# categories:
# *  seller - change privat to "private" (fixed)
# *  offer_type - "Angebot" to "offer" (fixed)
# *  vehicle_type - "kleinwagen" to "sedan", "kombi" to "station_wagon", "andere" to "other"
# *  gearbox - change "manuell" to "manual" and "automatik" to "automatic" (fixed)
# *  fuel_type - change "elektro" to "electric" (fixed)
# *  unrepaired_damage - "nein" to "no" and "ja" to "yes" (fixed)

# %%
autos["vehicle_type"].unique()
# Out:
# array(['bus', 'limousine', 'kleinwagen', 'kombi', nan, 'coupe', 'suv',
#        'cabrio', 'andere'], dtype=object)

# %%
#change seller
autos.loc[autos.loc[:,"seller"]=="privat","seller"]="private"
#change offer_type
autos.loc[autos.loc[:,"offer_type"]=="Angebot","offer_type"]="offer"
#change gearbox
autos.loc[autos.loc[:,"gearbox"]=="manuell","gearbox"]="manual"
autos.loc[autos.loc[:,"gearbox"]=="automatik","gearbox"]="automatic"
#change fuel_type
autos.loc[autos.loc[:,"fuel_type"]=="elektro","fuel_type"]="electric"
#change unrepaired_damage
autos.loc[autos.loc[:,"unrepaired_damage"]=="nein","unrepaired_damage"]="no"
autos.loc[autos.loc[:,"unrepaired_damage"]=="ja","unrepaired_damage"]="yes"
#change vehicle type
autos.loc[autos.loc[:,"vehicle_type"]=="kleinwagen","vehicle_type"]="sedan"
autos.loc[autos.loc[:,"vehicle_type"]=="kombi","vehicle_type"]="station_wagon"
autos.loc[autos.loc[:,"vehicle_type"]=="andere","vehicle_type"]="other"

# %% [markdown]
# Next Step #2: Convert the dates to be uniform numeric data so that the string "2016-03-21" becomes integer 20160321.
#
# This will affect columns date_crawled, ad_created, last_seen.

# %%
#change date columns to integers in YYYYMMDD format
autos["date_crawled"]=autos["date_crawled"].str[:10].str.replace("-","").astype("int")
autos["ad_created"]=autos["ad_created"].str[:10].str.replace("-","").astype("int")
autos["last_seen"]=autos["last_seen"].str[:10].str.replace("-","").astype("int")

# %%
print(autos["name"])
# Out:
# 0                         Peugeot_807_160_NAVTECH_ON_BOARD
# 1               BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2                               Volkswagen_Golf_1.6_United
# 3        Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4        Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5        Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6        VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7                                     Golf_IV_1.9_TDI_90PS
# 8                                               Seat_Arosa
# 9                Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10                            VW_Golf_Tuning_in_siber/grau
# 11                              Mercedes_A140_Motorschaden
# 12       Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13                                      Audi_A3_1.6_tuning
# 14       Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 15             Corvette_C3_Coupe_T_Top_Crossfire_Injection
# ...

# %% [markdown]
# Next Step #3: See if there are any particular keywords in the name column that you can extract as new columns?
#
# I'm not sure what I would want to pull out of the name column.

# %% [markdown]
# Next Step #4: Find the most common brand/model combinations.

# %%
autos["brand_model"]=autos["brand"]+" "+autos["model"]

autos["brand_model"].value_counts().head(10)
# Out:
# volkswagen golf           3824
# bmw 3er                   2649
# volkswagen polo           1634
# opel corsa                1617
# opel astra                1377
# volkswagen passat         1370
# audi a4                   1244
# mercedes_benz c_klasse    1154
# bmw 5er                   1136
# mercedes_benz e_klasse     965
# Name: brand_model, dtype: int64

# %% [markdown]
# Observation: The most popular brand model combination is volkswagen golf.

# %% [markdown]
# Next Step #5: Split the odometer_km into groups, and use aggregation to see if average prices follow any patterns based on mileage.

# %%
autos["odometer_km"].value_counts().sort_index(ascending=False)
# Out:
# 150000    30795
# 125000     4982
# 100000     2076
# 90000      1712
# 80000      1395
# 70000      1202
# 60000      1145
# 50000      1004
# 40000       811
# 30000       771
# 20000       752
# 10000       238
# 5000        725
# Name: odometer_km, dtype: int64

# %%
#created four groups: "sub_40000", "40000_90000", "90000_125000","above_125000"
autos.loc[autos.loc[:,"odometer_km"].between(0,40000),"odom_group"]="sub_40000"
autos.loc[autos.loc[:,"odometer_km"].between(40000,90000),"odom_group"]="40000_90000"
autos.loc[autos.loc[:,"odometer_km"].between(90000,125000),"odom_group"]="90000_125000"
autos.loc[autos.loc[:,"odometer_km"]>125000,"odom_group"]="above_125000"

# %%
avg_by_group={}
for car in autos["odom_group"].unique():
    selected_rows=autos[autos["odom_group"]==car]
    new_avg=selected_rows["price"].mean(axis=0)
    avg_by_group[car]=new_avg.round(2)

avg_by_group
# Out:
# {'40000_90000': 12318.46,
#  '90000_125000': 7200.81,
#  'above_125000': 3875.09,
#  'sub_40000': 17075.3}

# %% [markdown]
# In creating a few odometer categories, I can observe that there is a negative correlation between odometer reading and avg vehicle price.

# %%
avg_by_damage={}
for car in autos["unrepaired_damage"].unique():
    selected_rows=autos[autos["unrepaired_damage"]==car]
    avg_price=selected_rows["price"].mean(axis=0)
    avg_by_damage[car]=avg_price

avg_by_damage
# Out:
# {nan: nan, 'no': 7303.619607843138, 'yes': 2492.3204734765454}

# %% [markdown]
# Observation: In comparing vehicles with unrepaired damage and with repaired damage, I can conclude that vehicles for sale which do not have any needed repairs are about 3x more expensive than those with necessary repairs.

# %%
autos["date_crawled"].value_counts().sort_index()
# Out:
# 20160305    1209
# 20160306     673
# 20160307    1716
# 20160308    1584
# 20160309    1579
# 20160310    1542
# 20160311    1556
# 20160312    1754
# 20160313     751
# 20160314    1735
# 20160315    1625
# 20160316    1405
# 20160317    1503
# 20160318     609
# 20160319    1651
# 20160320    1798
# 20160321    1772
# 20160322    1568
# 20160323    1537
# 20160324    1401
# 20160325    1495
# 20160326    1534
# 20160327    1483
# 20160328    1671
# 20160329    1628
# 20160330    1611
# 20160331    1504
# 20160401    1605
# 20160402    1692
# 20160403    1838
# 20160404    1742
# 20160405     621
# 20160406     150
# 20160407      66
# Name: date_crawled, dtype: int64

# %%
#created a function that creates a dictionary aggregated average as the value with a category as the key
def new_dict(input1,input2):
    avg_dict={}
    for car in autos[input1].unique():
        selected_rows=autos[autos[input1]==car]
        avg_value=selected_rows[input2].mean(axis=0)
        avg_dict[car]=avg_value
    return avg_dict

# %%
#my new_dict() function results match my previous results
new_dict("unrepaired_damage","price")
# Out:
# {nan: nan, 'no': 7303.619607843138, 'yes': 2492.3204734765454}
